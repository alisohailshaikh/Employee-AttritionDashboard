# %%
import pandas as pd

data = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# Education:
# 1 :'Below College'
# 2 :'College'
# 3 :'Bachelor'
# 4 :'Master'
# 5 :'Doctor'

# %%
data['Education'] = data['Education'].replace({1: 'Below College', 2: 'College', 3: 'Bachelor', 4: 'Master', 5: 'Doctor'})

# %%
data['EnvironmentSatisfaction'] = data['EnvironmentSatisfaction'].replace({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})

# %%
data['JobInvolvement'] = data['JobInvolvement'].replace({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})

# %%
data['JobSatisfaction'] = data['JobSatisfaction'].replace({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})

# %%
data['PerformanceRating'] = data['PerformanceRating'].replace({1: 'Low', 2: 'Good', 3: 'Excellent', 4: 'Outstanding'})

# %%
data['RelationshipSatisfaction'] = data['RelationshipSatisfaction'].replace({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})

# %%
data['WorkLifeBalance'] = data['WorkLifeBalance'].replace({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 4                 2  Below College        Medical              1
#
#    EmployeeNumber  ... RelationshipSatisfaction StandardHours  \
# 0               1  ...                      Low            80
# ...

# %%
data = data.drop(columns=['EmployeeCount','StandardHours','EmployeeNumber'],axis=1)

# %%
data['Attrition']=data['Attrition'].replace({'Yes' : 1 , 'No' : 0})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_corr = data.corr()
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3588\2649001907.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_corr = data.corr()
# C:\Users\User\AppData\Local\Temp\ipykernel_3588\2649001907.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
# <Axes: >

# %%
bins = [18, 25, 35, 45, 60]
labels = ['18-25', '26-35', '36-45', '46-60']
data['AgeGroup'] = pd.cut(data['Age'], bins=bins, labels=labels, include_lowest=True)

# %%
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                 1        College  Life Sciences                  Medium
# 1                 8  Below College  Life Sciences                    High
# 2                 2        College          Other               Very High
# 3                 3         Master  Life Sciences               Very High
# 4                 2  Below College        Medical                     Low
#
#    Gender  ...  RelationshipSatisfaction StockOptionLevel  TotalWorkingYears  \
# ...

# %%
sns.histplot(data['AgeGroup'])
# Out:
# <Axes: xlabel='AgeGroup', ylabel='Count'>

# %% [markdown]
# Pain Area: Reduce Attrition rate further

# %%
sns.histplot(data['Attrition'])
# Out:
# <Axes: xlabel='Attrition', ylabel='Count'>

# %%
sns.histplot(data['BusinessTravel'])
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='Count'>

# %%
sns.boxplot(data['DailyRate'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['MonthlyRate'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['MonthlyIncome'])
# Out:
# <Axes: >

# %%
sns.histplot(data['Department'])
# Out:
# <Axes: xlabel='Department', ylabel='Count'>

# %%
min_value = 1
max_value = 30
bin_size = 5

# Create bins
bins = range(min_value, max_value + bin_size, bin_size)
labels = [f"{i} to {i + bin_size - 1}" for i in bins[:-1]]

data['CommuteDistance'] = pd.cut(data['DistanceFromHome'], bins=bins, labels=labels, include_lowest=True)

# %%
data.head(30)
# Out:
#     Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0    41          1      Travel_Rarely       1102                   Sales
# 1    49          0  Travel_Frequently        279  Research & Development
# 2    37          1      Travel_Rarely       1373  Research & Development
# 3    33          0  Travel_Frequently       1392  Research & Development
# 4    27          0      Travel_Rarely        591  Research & Development
# 5    32          0  Travel_Frequently       1005  Research & Development
# 6    59          0      Travel_Rarely       1324  Research & Development
# 7    30          0      Travel_Rarely       1358  Research & Development
# 8    38          0  Travel_Frequently        216  Research & Development
# 9    36          0      Travel_Rarely       1299  Research & Development
# 10   35          0      Travel_Rarely        809  Research & Development
# 11   29          0      Travel_Rarely        153  Research & Development
# ...

# %%
print(data['DistanceFromHome'])
# Out:
# 0        1
# 1        8
# 2        2
# 3        3
# 4        2
#         ..
# 1465    23
# 1466     6
# 1467     4
# 1468     2
# 1469     8
# Name: DistanceFromHome, Length: 1470, dtype: int64

# %%
print(data['CommuteDistance'])
# Out:
# 0         1 to 5
# 1        6 to 10
# 2         1 to 5
# 3         1 to 5
# 4         1 to 5
#           ...
# 1465    21 to 25
# 1466      1 to 5
# 1467      1 to 5
# 1468      1 to 5
# 1469     6 to 10
# Name: CommuteDistance, Length: 1470, dtype: category
# Categories (6, object): ['1 to 5' < '6 to 10' < '11 to 15' < '16 to 20' < '21 to 25' < '26 to 30']

# %%
sns.histplot(data['CommuteDistance'])
# Out:
# <Axes: xlabel='CommuteDistance', ylabel='Count'>

# %%
sns.histplot(data['Education'])
# Out:
# <Axes: xlabel='Education', ylabel='Count'>

# %%
sns.histplot(data['EducationField'])
# Out:
# <Axes: xlabel='EducationField', ylabel='Count'>

# %%
sns.histplot(data['JobInvolvement'])
# Out:
# <Axes: xlabel='JobInvolvement', ylabel='Count'>

# %%
sns.histplot(data['JobLevel'])
# Out:
# <Axes: xlabel='JobLevel', ylabel='Count'>

# %%
sns.histplot(data['JobRole'])
# Out:
# <Axes: xlabel='JobRole', ylabel='Count'>

# %%
sns.boxplot(data['MonthlyIncome'])
# Out:
# <Axes: >

# %%
min_value = 1000
max_value = 19999
bin_size = 5000  


bins = range(min_value, max_value + bin_size, bin_size)
labels = [f"{i} to {i + bin_size - 1}" for i in bins[:-1]]

# Create a new column 'IncomeGroup' with the bin labels
data['IncomeRange'] = pd.cut(data['MonthlyIncome'], bins=bins, labels=labels, include_lowest=True)

# %%
print(data['IncomeRange'])
# Out:
# 0        1000 to 5999
# 1        1000 to 5999
# 2        1000 to 5999
# 3        1000 to 5999
# 4        1000 to 5999
#             ...
# 1465     1000 to 5999
# 1466    6000 to 10999
# 1467    6000 to 10999
# 1468     1000 to 5999
# 1469     1000 to 5999
# Name: IncomeRange, Length: 1470, dtype: category
# Categories (4, object): ['1000 to 5999' < '6000 to 10999' < '11000 to 15999' < '16000 to 20999']

# %%
print(data['MonthlyIncome'])
# Out:
# 0       5993
# 1       5130
# 2       2090
# 3       2909
# 4       3468
#         ...
# 1465    2571
# 1466    9991
# 1467    6142
# 1468    5390
# 1469    4404
# Name: MonthlyIncome, Length: 1470, dtype: int64

# %%
sns.histplot(data['OverTime'])
# Out:
# <Axes: xlabel='OverTime', ylabel='Count'>

# %%
min_value = 0
max_value = 40
bin_size = 5


bins = range(min_value, max_value + bin_size, bin_size)
labels = [f"{i} to {i + bin_size - 1}" for i in bins[:-1]]

data['WorkYearRange'] = pd.cut(data['TotalWorkingYears'], bins=bins, labels=labels, include_lowest=True)

# %%
min_value = 0
max_value = 40
bin_size = 5


bins = range(min_value, max_value + bin_size, bin_size)
labels = [f"{i} to {i + bin_size - 1}" for i in bins[:-1]]

data['CompanyYearRange'] = pd.cut(data['YearsAtCompany'], bins=bins, labels=labels, include_lowest=True)

# %%
min_value = 0
max_value = 18
bin_size = 3

bins = range(min_value, max_value + bin_size, bin_size)
labels = [f"{i} to {i + bin_size - 1}" for i in bins[:-1]]


data['YearsAtCurrentRoleGroup'] = pd.cut(data['YearsInCurrentRole'], bins=bins, labels=labels, include_lowest=True)

# %%
min_value = 0
max_value = 18
bin_size = 3

bins = range(min_value, max_value + bin_size, bin_size)
labels = [f"{i} to {i + bin_size - 1}" for i in bins[:-1]]


data['YearsPromotionGroup'] = pd.cut(data['YearsSinceLastPromotion'], bins=bins, labels=labels, include_lowest=True)

# %%
min_value = 0
max_value = 17
bin_size = 3

bins = range(min_value, max_value + bin_size, bin_size)
labels = [f"{i} to {i + bin_size - 1}" for i in bins[:-1]]


data['YearsManagerGroup'] = pd.cut(data['YearsWithCurrManager'], bins=bins, labels=labels, include_lowest=True)

# %%
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                 1        College  Life Sciences                  Medium
# 1                 8  Below College  Life Sciences                    High
# 2                 2        College          Other               Very High
# 3                 3         Master  Life Sciences               Very High
# 4                 2  Below College        Medical                     Low
#
#    Gender  ...  YearsSinceLastPromotion YearsWithCurrManager  AgeGroup  \
# ...

# %%
data.to_csv("BI Project clean+eda data.csv")

# %%
sns.histplot(data['JobSatisfaction'])
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='Count'>

# %%
data.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome   HourlyRate  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517    65.891156
# std       9.135373     0.367863   403.509100          8.106864    20.329428
# min      18.000000     0.000000   102.000000          1.000000    30.000000
# 25%      30.000000     0.000000   465.000000          2.000000    48.000000
# 50%      36.000000     0.000000   802.000000          7.000000    66.000000
# 75%      43.000000     0.000000  1157.000000         14.000000    83.750000
# max      60.000000     1.000000  1499.000000         29.000000   100.000000
#
#           JobLevel  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count  1470.000000    1470.000000   1470.000000         1470.000000
# mean      2.063946    6502.931293  14313.103401            2.693197
# std       1.106940    4707.956783   7117.786044            2.498009
# ...

# %%
sns.histplot(data['PerformanceRating'])
# Out:
# <Axes: xlabel='PerformanceRating', ylabel='Count'>

# %%
data['OverTime']=data['OverTime'].replace({'Yes' : 1 , 'No' : 0})

# %%
data_corr = data.corr()
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3588\2649001907.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_corr = data.corr()
# C:\Users\User\AppData\Local\Temp\ipykernel_3588\2649001907.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
# <Axes: >

# %%
sns.histplot(data['OverTime'])
# Out:
# <Axes: xlabel='OverTime', ylabel='Count'>

# %%
sns.scatterplot(x=data['Attrition'],y=data['OverTime'])
# Out:
# <Axes: xlabel='Attrition', ylabel='OverTime'>

# %%
data['Bonus'] = data['MonthlyIncome'] - data['MonthlyRate']

# %%
data['Bonus']
# Out:
# 0      -13486
# 1      -19777
# 2        -306
# 3      -20250
# 4      -13164
#         ...
# 1465    -9719
# 1466   -11466
# 1467      968
# 1468    -7853
# 1469    -5824
# Name: Bonus, Length: 1470, dtype: int64

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(data['JobSatisfaction'], data['Attrition'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Interpret the results
print(f"Chi2 Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Contingency Table:")
print(expected)
# Out:
# Chi2 Statistic: 17.505077010348
# P-value: 0.0005563004510387556
# Degrees of Freedom: 3
# Contingency Table:
# [[370.73877551  71.26122449]
#  [242.40612245  46.59387755]
#  [234.85714286  45.14285714]
#  [384.99795918  74.00204082]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(data['JobInvolvement'], data['Attrition'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Interpret the results
print(f"Chi2 Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Contingency Table:")
print(expected)
# Out:
# Chi2 Statistic: 28.492021234659283
# P-value: 2.8631806367134195e-06
# Degrees of Freedom: 3
# Contingency Table:
# [[728.05714286 139.94285714]
#  [ 69.61836735  13.38163265]
#  [314.54081633  60.45918367]
#  [120.78367347  23.21632653]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(data['EnvironmentSatisfaction'], data['Attrition'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Interpret the results
print(f"Chi2 Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Contingency Table:")
print(expected)
# Out:
# Chi2 Statistic: 22.503881435842292
# P-value: 5.1234689062894327e-05
# Degrees of Freedom: 3
# Contingency Table:
# [[379.96530612  73.03469388]
#  [238.2122449   45.7877551 ]
#  [240.72857143  46.27142857]
#  [374.09387755  71.90612245]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(data['RelationshipSatisfaction'], data['Attrition'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Interpret the results
print(f"Chi2 Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Contingency Table:")
print(expected)
# Out:
# Chi2 Statistic: 5.241067859713708
# P-value: 0.1549724437105263
# Degrees of Freedom: 3
# Contingency Table:
# [[384.99795918  74.00204082]
#  [231.50204082  44.49795918]
#  [254.14897959  48.85102041]
#  [362.35102041  69.64897959]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(data['WorkLifeBalance'], data['Attrition'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Interpret the results
print(f"Chi2 Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Contingency Table:")
print(expected)
# Out:
# Chi2 Statistic: 16.3250970916474
# P-value: 0.0009725698845348824
# Degrees of Freedom: 3
# Contingency Table:
# [[749.02653061 143.97346939]
#  [ 67.10204082  12.89795918]
#  [288.53877551  55.46122449]
#  [128.33265306  24.66734694]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(data['CommuteDistance'], data['Attrition'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Interpret the results
print(f"Chi2 Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Contingency Table:")
print(expected)
# Out:
# Chi2 Statistic: 17.417122382897013
# P-value: 0.0037730251898568912
# Degrees of Freedom: 5
# Contingency Table:
# [[579.59387755 111.40612245]
#  [305.31428571  58.68571429]
#  [ 98.9755102   19.0244898 ]
#  [ 93.10408163  17.89591837]
#  [104.00816327  19.99183673]
#  [ 52.00408163   9.99591837]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(data['OverTime'], data['Attrition'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Interpret the results
print(f"Chi2 Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Contingency Table:")
print(expected)
# Out:
# Chi2 Statistic: 87.56429365828768
# P-value: 8.15842372153832e-21
# Degrees of Freedom: 1
# Contingency Table:
# [[884.06938776 169.93061224]
#  [348.93061224  67.06938776]]
